# %% [markdown]
# # Test API Hugging Face:
#
# Salesforce/blip-image-captioning-base

# %%
# image_description_api.py

import requests
import os
from dotenv import load_dotenv

from transformers import BlipProcessor, BlipForConditionalGeneration
import cv2
import torch

load_dotenv()
# Out:
# True

# %%
# loading model
processor = BlipProcessor.from_pretrained(
    "Salesforce/blip-image-captioning-base",
    trust_remote_code=True  # обязательно для BLIP
)
model = BlipForConditionalGeneration.from_pretrained(
    "Salesforce/blip-image-captioning-base",
    trust_remote_code=True
)
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`

# %%
img = cv2.imread("IMG_20240323_145042.jpg")
inputs = processor(images=img, return_tensors="pt")
out = model.generate(**inputs)
caption = processor.decode(out[0], skip_special_tokens=True)
print("Generated caption:", caption)
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Generated caption: a couple of palm trees sitting on a sidewalk

# %%
from transformers import file_utils

cache_dir = file_utils.default_cache_path
print("Transformers cache directory:", cache_dir)
# Out:
# Transformers cache directory: C:\Users\Hanna\.cache\huggingface\hub
